# %% [markdown]
# ## Validation of additional silver tables to bronze tables

# %%
# Validation of sl_dev_customer to br_customers 

# br_customer 
br_cust = spark.read.table('bronze_shortcut.br_customers')

print('==== Bronze Cust Schema ====')
br_cust.printSchema()

br_cust_rows = br_cust.count()
br_cust_columns = len(br_cust.columns)
print(f'Rows = {br_cust_rows}, Columns = {br_cust_columns}')
print('\n')

#sl_dev_customer
print('==== Silver Cust Schema ====')
sl_dev_cust = spark.read.table('dbo.sl_dev_customers')

sl_dev_cust.printSchema()

sl_dev_cust_rows = sl_dev_cust.count()
sl_dev_cust_columns = len(sl_dev_cust.columns)
print(f'Rows = {sl_dev_cust_rows}, Columns = {sl_dev_cust_columns}')
# Out:
# StatementMeta(, 851a5dab-579c-4978-9d85-a31cf44ec2ed, 9, Finished, Available, Finished)
# ==== Bronze Cust Schema ====
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#
# Rows = 99441, Columns = 5
#
#
# ==== Silver Cust Schema ====
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#
# Rows = 99441, Columns = 5

# %%
# Validation of sl_dev_geolocation to br_geolocation 

# br_geolocation
br_geolocation = spark.read.table('bronze_shortcut.br_geolocation')

print('==== Bronze Geolocation Schema ====')
br_geolocation.printSchema()

br_geolocation_rows = br_geolocation.count()
br_geolocation_columns = len(br_geolocation.columns)
print(f'Rows = {br_geolocation_rows}, Columns = {br_geolocation_columns}')
print('\n')

#sl_dev_geolocation
print('==== Silver Geolocation Schema ====')
sl_dev_geolocation = spark.read.table('dbo.sl_dev_geolocation')

sl_dev_geolocation.printSchema()

sl_dev_geolocation_rows = sl_dev_geolocation.count()
sl_dev_geolocation_columns = len(sl_dev_geolocation.columns)
print(f'Rows = {sl_dev_geolocation_rows}, Columns = {sl_dev_geolocation_columns}')
# Out:
# StatementMeta(, 851a5dab-579c-4978-9d85-a31cf44ec2ed, 15, Finished, Available, Finished)
# ==== Bronze Geolocation Schema ====
# root
#  |-- geolocation_zip_code_prefix: string (nullable = true)
#  |-- geolocation_lat: string (nullable = true)
#  |-- geolocation_lng: string (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#
# Rows = 1000163, Columns = 5
#
#
# ==== Silver Geolocation Schema ====
# root
#  |-- geolocation_zip_code_prefix: string (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#
# Rows = 1000163, Columns = 5

# %%
# Validation of sl_dev_payments to br_payments

# br_payments
br_payments = spark.read.table('bronze_shortcut.br_payments')

print('==== Bronze Geolocation Schema ====')
br_payments.printSchema()

br_payments_rows = br_payments.count()
br_payments_columns = len(br_payments.columns)
print(f'Rows = {br_payments_rows}, Columns = {br_payments_columns}')
print('\n')

#sl_dev_payments
print('==== Silver Geolocation Schema ====')
sl_dev_payments = spark.read.table('dbo.sl_dev_payments')

sl_dev_payments.printSchema()

sl_dev_payments_rows = sl_dev_payments.count()
sl_dev_payments_columns = len(sl_dev_payments.columns)
print(f'Rows = {sl_dev_payments_rows}, Columns = {sl_dev_payments_columns}')
# Out:
# StatementMeta(, 851a5dab-579c-4978-9d85-a31cf44ec2ed, 16, Finished, Available, Finished)
# ==== Bronze Geolocation Schema ====
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: string (nullable = true)
#  |-- payment_value: string (nullable = true)
#
# Rows = 103886, Columns = 5
#
#
# ==== Silver Geolocation Schema ====
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)
#
# Rows = 103886, Columns = 5

# %%
# Validation of sl_dev_products to br_products

# br_products
br_products = spark.read.table('bronze_shortcut.br_products')

print('==== Bronze Products Schema ====')
br_products.printSchema()

br_products_rows = br_products.count()
br_products_columns = len(br_products.columns)
print(f'Rows = {br_products_rows}, Columns = {br_products_columns}')
print('\n')

#sl_dev_products
print('==== Silver Products Schema ====')
sl_dev_products = spark.read.table('dbo.sl_dev_products')

sl_dev_products.printSchema()

sl_dev_products_rows = sl_dev_products.count()
sl_dev_products_columns = len(sl_dev_products.columns)
print(f'Rows = {sl_dev_products_rows}, Columns = {sl_dev_products_columns}')
# Out:
# StatementMeta(, 851a5dab-579c-4978-9d85-a31cf44ec2ed, 17, Finished, Available, Finished)
# ==== Bronze Products Schema ====
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: string (nullable = true)
#  |-- product_description_lenght: string (nullable = true)
#  |-- product_photos_qty: string (nullable = true)
#  |-- product_weight_g: string (nullable = true)
#  |-- product_length_cm: string (nullable = true)
#  |-- product_height_cm: string (nullable = true)
#  |-- product_width_cm: string (nullable = true)
#
# Rows = 32951, Columns = 9
#
#
# ==== Silver Products Schema ====
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: double (nullable = true)
# ...

# %%
# Validation of sl_dev_product_category_translation to br_product_category_translation

# br_product_category_translation
br_product_category_translation = spark.read.table('bronze_shortcut.br_product_category_translation')

print('==== Bronze Product Category Translation Schema ====')
br_product_category_translation.printSchema()

br_product_category_translation_rows = br_product_category_translation.count()
br_product_category_translation_columns = len(br_product_category_translation.columns)
print(f'Rows = {br_product_category_translation_rows}, Columns = {br_product_category_translation_columns}')
print('\n')

#sl_dev_product_category_translation
print('==== Silver Product Category Translation Schema ====')
sl_dev_product_category_translation = spark.read.table('dbo.sl_dev_product_category_translation')

sl_dev_product_category_translation.printSchema()

sl_dev_product_category_translation_rows = sl_dev_product_category_translation.count()
sl_dev_product_category_translation_columns = len(sl_dev_product_category_translation.columns)
print(f'Rows = {sl_dev_product_category_translation_rows}, Columns = {sl_dev_product_category_translation_columns}')
# Out:
# StatementMeta(, 851a5dab-579c-4978-9d85-a31cf44ec2ed, 18, Finished, Available, Finished)
# ==== Bronze Product Category Translation Schema ====
# root
#  |-- product_category_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)
#
# Rows = 71, Columns = 2
#
#
# ==== Silver Product Category Translation Schema ====
# root
#  |-- product_category_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)
#
# Rows = 71, Columns = 2
